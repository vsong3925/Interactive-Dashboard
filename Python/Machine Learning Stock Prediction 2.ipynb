# %%
import pandas as pd
from flask import Flask, request, render_template, jsonify
from config import remote_db_endpoint, remote_db_port, remote_db_user, remote_db_pwd, remote_db_name
import pandas as pd

# %%
from flask import Flask, request, render_template, jsonify
from config import remote_db_endpoint, remote_db_port, remote_db_user, remote_db_pwd, remote_db_name
import pymysql
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import create_engine

# %%
import pymysql
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import create_engine

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from config import api_key
import requests
import json

# %% [markdown]
# ## Read Data: SP500

# %%
pymysql.install_as_MySQLdb()
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")

# %%
pymysql.install_as_MySQLdb()
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
conn = engine.connect()

# %%
query = '''
select * from SP500
'''

data = pd.read_sql(query, conn)
data.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close      Volume
# 0  2000-01-03  1469  1478  1438   1455       1455   931800000
# 1  2000-01-04  1455  1455  1397   1399       1399  1009000000
# 2  2000-01-05  1399  1413  1378   1402       1402  1085500000
# 3  2000-01-06  1402  1412  1392   1403       1403  1092300000
# 4  2000-01-07  1403  1441  1401   1441       1441  1225200000

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Close Prices')
plt.plot(data['Close'])
plt.title('Altaba Inc. closing price')
plt.show()

# %%
df_close = data['Close']
df_close.plot(style='k.')
plt.title('Scatter plot of closing price')
plt.show()

# %% [markdown]
# ## check for stationarity

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
    
test_stationarity(df_close)
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e758f5f0f9ec> in <module>
#      21     print(output)
#      22
# ---> 23 test_stationarity(df_close)
#
# <ipython-input-18-e758f5f0f9ec> in test_stationarity(timeseries)
#      13
#      14     print("Results of dickey fuller test")
# ---> 15     adft = adfuller(timeseries,autolag='AIC')
#      16     # output for dft will give us without defining what the values are.
#      17     #hence we manually write what values does it explains using a for loop
#
# NameError: name 'adfuller' is not defined

# %%
result = seasonal_decompose(df_close, model='multiplicative', freq = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7d28f8538da7> in <module>
# ----> 1 result = seasonal_decompose(df_close, model='multiplicative', freq = 30)
#       2 fig = plt.figure()
#       3 fig = result.plot()
#       4 fig.set_size_inches(16, 9)
#
# NameError: name 'seasonal_decompose' is not defined

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find             optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-52357ba0f39d> in <module>
# ----> 1 model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
#       2                       test='adf',       # use adftest to find             optimal 'd'
#       3                       max_p=3, max_q=3, # maximum p and q
#       4                       m=1,              # frequency of series
#       5                       d=None,           # let model determine 'd'
#
# NameError: name 'auto_arima' is not defined

# %%
# Forecast
fc, se, conf = fitted.forecast(544, alpha=0.05)  # 95% confidence
fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, color = 'blue', label='Actual Stock Price')
plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.title('Altaba Inc. Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-66e49ff69498> in <module>
#       1 # Forecast
# ----> 2 fc, se, conf = fitted.forecast(544, alpha=0.05)  # 95% confidence
#       3 fc_series = pd.Series(fc, index=test_data.index)
#       4 lower_series = pd.Series(conf[:, 0], index=test_data.index)
#       5 upper_series = pd.Series(conf[:, 1], index=test_data.index)
#
# NameError: name 'fitted' is not defined
